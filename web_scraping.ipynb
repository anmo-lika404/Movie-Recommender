# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
headers = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36',
           'Accept-Language': 'en-US, en;q=0.5'})

# %%
movie_name = []
year = []
time=[]
rating=[]
metascore =[]
director=[]
votes = []
gross = []
description = []
genre=[]
cast=[]
cas=[]
pages = np.arange(1,1000,50)
#https://www.imdb.com/search/title/?title_type=feature&primary_language=en
#https://www.imdb.com/search/title/?title_type=feature&primary_language=en&ref_=adv_prv

# %%
for page in pages:
    page = requests.get("https://www.imdb.com/search/title/?title_type=feature&primary_language=en&start="+str(page)+"&ref_=adv_nxt")
    soup = BeautifulSoup(page.text, 'html.parser')
    movie_data = soup.findAll('div', attrs = {'class': 'lister-item mode-advanced'})
    for store in movie_data:
        name = store.h3.a.text
        movie_name.append(name)
        
        year_of_release = store.h3.find('span', class_ = "lister-item-year text-muted unbold").text.replace('(', '')
        year_of_release=year_of_release.replace(')','')
        year.append(year_of_release)
        
        runtime = store.p.find("span", class_ = 'runtime').text if store.find('span', class_ = "runtime") else "NA"
        time.append(runtime)
        
        gen = store.p.find("span", class_ = 'genre').text
        genre.append(gen)
        
        rate = store.find('div', class_ = "inline-block ratings-imdb-rating").text.replace('\n', '') if store.find('div', class_ = "inline-block ratings-imdb-rating") else "NA"
        rating.append(rate)
        #rate = store.find('div', class_ = "ratings-bar").find('strong').text.replace('\n', '')
        #rating.append(rate)
        
        meta = store.find('span', class_ = "metascore").text if store.find('span', class_ = "metascore") else "NA"#if meta score not present then *
        
        metascore.append(meta)
        
        #dire=store.find('p',class_ = "metascore")
        dire=store.find('p',class_='').find_all('a')[0].text
        
        director.append(dire)
        
        #cas=([a.text for a in store.find('p',class_='').find_all('a')[1:]])
        #cast=','.join(map(str,cas))
        cast.append([a.text for a in store.find('p',class_='').find_all('a')[1:]])
      
        value = store.find_all('span', attrs = {'name':'nv'}) if store.find_all('span', attrs = {'name':'nv'}) else 'NA'
        vote = value[0].text if store.find_all('span', attrs = {'name':'nv'}) else 'NA'

        #vote = value[0].text if len(value)>1 else 'NA'
        votes.append(vote)
        
        #grosses = value[1].text if len(value)>1 else 'NA'
        #gross.append(grosses)
        
      
        describe = store.find_all('p', class_ = 'text-muted')
        description_ = describe[1].text.replace('\n', '') if len(describe) >1 else 'NA'
        description.append(description_)

# %%
for i in cast:
    c=','.join(map(str,i))
    cas.append(c)

# %%
movie_list = pd.DataFrame({ "Title": movie_name, "Year of Release" : year, "Watch Time": time,"Genre":genre,"Movie Rating": rating, "Metascore of movie": metascore,"Director":director,"Cast":cas,"Votes" : votes,"Description": description})
movie_list.to_excel("movie data_new1.xlsx")

# %%
movie_list
# Out:
#                        Title Year of Release Watch Time  \
# 0                    Encanto            2021    102 min
# 1    Spider-Man: No Way Home            2021    148 min
# 2                   Eternals            2021    156 min
# 3    Munich: The Edge of War            2021    130 min
# 4                     Scream          I 2022    114 min
# ..                       ...             ...        ...
# 995                     Vivo          I 2021     95 min
# 996             The Bad Guys            2022         NA
# 997              The Marvels            2023         NA
# 998           Gone Baby Gone            2007    114 min
# 999                 Oblivion          I 2013    124 min
#
#                                           Genre Movie Rating  \
# 0       \nAnimation, Comedy, Family                      7.3
# 1      \nAction, Adventure, Fantasy                      8.7
# 2      \nAction, Adventure, Fantasy                      6.5
# 3       \nBiography, Drama, History                      6.9
# 4       \nHorror, Mystery, Thriller                      7.1
# ..                                          ...          ...
# 995  \nAnimation, Adventure, Comedy                      6.7
# 996  \nAnimation, Adventure, Comedy                       NA
# 997    \nAction, Adventure, Fantasy                       NA
# 998         \nCrime, Drama, Mystery                      7.6
# 999     \nAction, Adventure, Sci-Fi                      7.0
#
#     Metascore of movie               Director  \
# 0           76                     Jared Bush
# 1           71                      Jon Watts
# 2           52                     Chloé Zhao
# 3           53            Christian Schwochow
# 4           60          Matt Bettinelli-Olpin
# ..                 ...                    ...
# 995         66                   Kirk DeMicco
# 996                 NA         Pierre Perifel
# 997                 NA            Nia DaCosta
# 998         72                    Ben Affleck
# 999         54                Joseph Kosinski
#
#                                                   Cast    Votes  \
# 0    Byron Howard,Charise Castro Smith,Stephanie Be...  123,730
# 1    Tom Holland,Zendaya,Benedict Cumberbatch,Jacob...  436,702
# 2    Gemma Chan,Richard Madden,Angelina Jolie,Salma...  236,952
# 3    George MacKay,Jannis Niewöhner,Jeremy Irons,Li...   13,506
# 4    Tyler Gillett,Neve Campbell,Courteney Cox,Davi...   34,989
# ..                                                 ...      ...
# 995  Brandon Jeffords,Lin-Manuel Miranda,Ynairaly S...   16,290
# 996    Sam Rockwell,Awkwafina,Anthony Ramos,Marc Maron       NA
# 997  Brie Larson,Samuel L. Jackson,Zawe Ashton,Teyo...       NA
# 998  Morgan Freeman,Ed Harris,Casey Affleck,Michell...  266,657
# 999  Tom Cruise,Morgan Freeman,Andrea Riseborough,O...  508,848
#
#                                            Description
# 0    A young Colombian woman has to face the frustr...
# 1    With Spider-Man's identity now revealed, Peter...
# 2    The saga of the Eternals, a race of immortal b...
# 3    A British diplomat travels to Munich in the ru...
# 4    Twenty-five years after the original series of...
# ..                                                 ...
# 995  Vivo, Sony Pictures Animation's first-ever mus...
# 996  Several reformed yet misunderstood criminal an...
# 997         Sequel of the 2019 title 'Captain Marvel'.
# 998  Two Boston area detectives investigate a littl...
# 999  A veteran assigned to extract Earth's remainin...
#
# [1000 rows x 10 columns]
